# %% [markdown]
# 给你一棵二叉树的根节点 root ，翻转这棵二叉树，并返回其根节点。
#
# ![image.png](attachment:image.png)

# %%
class Solution:
    def invertTree(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        if not root:
            return
        left = self.invertTree(root.left)
        right = self.invertTree(root.right)
        root.left = right
        root.right = left

        return root

# %% [markdown]
# 递推公式：
# 递归遍历翻转左子树；
# 递归遍历翻转右子树；
# 交换当前根节点 root 的左右子树
#
# 写递归不要想子问题的过程，否则会被绕晕
# 反转树只要知道对于root来说就是将反转后的左子树和反转后的右子树互换就ok了
