# %%
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        res = []

        def traverse(root):  # 这里相当于写一个遍历的函数，然后再调用函数
            if not root:
                return
            res.append(root.val)
            traverse(root.left)
            traverse(root.right)

        traverse(root)
        return res

# %% [markdown]
# 前序遍历就是按照深度优先的惯用思维，按照我们学算法之前的想法进行遍历，同时也是最好理解的

# %%
# 用遍历的思路计算前序遍历结果
class Solution:
    def __init__(self):
        self.res = []
    
    def preorderTraversal(self, root: TreeNode) -> List[int]:
        self.traverse(root)
        return self.res

    # 二叉树遍历函数
    def traverse(self, root: TreeNode):
        if root is None:
            return
        # 前序位置
        self.res.append(root.val)
        self.traverse(root.left)
        self.traverse(root.right)
